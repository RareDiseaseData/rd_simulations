# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/RareDiseaseData/rd_simulations/blob/main/sirion_plots.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Statistics representations

# %% [markdown]
# ## Import python libraries

# %%
import pandas as pd # work with data frames

import matplotlib.pyplot as plt # visual representation
import seaborn as sns # son of the above, but easier, kind of

# %%
df = pd.read_excel('data\collagen_marker.xlsx', sheet_name='OI data only') # reading the Excel file
df # showing the contents
# Out:
#     Code                 Author, year Sex Male Female  Type I  Type III  \
# 0    306            Zhang et al, 2022  MF   83     44   80.00     10.00
# 1    306            Zhang et al, 2022  MF    7     15   17.00      2.00
# 2    128    Hryhorovskyi et al., 2015  NR    x      x    1.00      0.00
# 3    128    Hryhorovskyi et al., 2015  NR    x      x    0.00      3.00
# 4    203              Xu et al., 2019   M    1      0    0.00      0.00
# 5    117             D’Eufemia., 2014  MF   11      7   18.00      0.00
# 6    118       D’Eufemia et al., 2017  MF    5      7   12.00      0.00
# 7    118       D’Eufemia et al., 2017  MF    4      2    6.00      0.00
# 8     30         Kitaoka et al., 2011   M    1      0    1.00      0.00
# 9     30         Kitaoka et al., 2011   M    1      0    1.00      0.00
# 10    30         Kitaoka et al., 2011   F    0      1    1.00      0.00
# 11    30         Kitaoka et al., 2011   M    1      0    1.00      0.00
# 12    30         Kitaoka et al., 2011   F    0      1    1.00      0.00
# 13    30         Kitaoka et al., 2011   M    1    NaN    1.00      0.00
# 14    30         Kitaoka et al., 2011   F    0      1    1.00      0.00
# 15    30         Kitaoka et al., 2011   M    1      0    1.00      0.00
# 16    30         Kitaoka et al., 2011   F    0      1    1.00      0.00
# 17    30         Kitaoka et al., 2011   M    1      0    1.00      0.00
# 18    30         Kitaoka et al., 2011   F    0      1    0.00      0.00
# 19    30         Kitaoka et al., 2011   M    1      0    0.00      0.00
# 20    30         Kitaoka et al., 2011   F    0      1    0.00      0.00
# 21   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 22    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 23    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 24    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 25    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 26    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 27    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 28    11         Pressac et al., 2002  MF    8      8    6.88      5.76
# 29    63         Iwamoto et al., 2002   M    1      0    1.00      0.00
# 30    69      Hoyer-Kuhn et al., 2019  MF    0      3     NaN      3.00
# 31    98  Zacharin & Kanumakala, 2004  NR    0      0    0.00      0.00
# 32   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 33   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 34   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 35   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 36   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 37   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 38   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 39   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 40   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 41   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN      0.00
# 42   202       Asharani  et al., 2012  NR    1      0    0.00      0.00
# 43   202       Asharani  et al., 2012  NR    1      0    0.00      0.00
# 44   206       Zacharin &Bateman 2002  NR    0      0    0.00      0.00
# 45    38           Rauch et al., 2002  MF   22     22   11.00     10.00
# 46    39          Uehara et al., 2017   F    0      1    1.00      0.00
# 47    39          Uehara et al., 2017   F    0      1    1.00      0.00
# 48    39          Uehara et al., 2017   F    0      1    1.00      0.00
# 49    63         Iwamoto et al., 2002   M    1      0    1.00      0.00
#
#     Type IV  Type V  Type XIII  ...  min age max age average age    n  \
# 0     24.00    13.0        0.0  ...    10.70   18.80       14.30  127
# 1      2.00     1.0        0.0  ...    30.60   49.80       38.30   22
# 2      0.00     0.0        0.0  ...     5.00   17.00       11.00    1
# 3      0.00     0.0        0.0  ...     5.00   17.00       11.00    3
# 4      0.00     0.0        1.0  ...     0.00    0.00       15.00    1
# 5      0.00     0.0        0.0  ...     2.60    6.20        4.40   18
# 6      0.00     0.0        0.0  ...     3.80    6.80        5.30   12
# 7      0.00     0.0        0.0  ...     3.10    5.30        4.20    6
# 8      0.00     0.0        0.0  ...     0.00    0.00        7.00    1
# 9      0.00     0.0        0.0  ...     0.00    0.00        4.00    1
# 10     0.00     0.0        0.0  ...     0.00    0.00       10.00    1
# 11     0.00     0.0        0.0  ...     0.00    0.00       12.00    1
# 12     0.00     0.0        0.0  ...     0.00    0.00        4.00    1
# 13     0.00     0.0        0.0  ...     0.00    0.00        4.00    1
# 14     0.00     0.0        0.0  ...     0.00    0.00        4.00    1
# 15     0.00     0.0        0.0  ...     0.00    0.00       14.00    1
# 16     0.00     0.0        0.0  ...     0.00    0.00       13.00    1
# 17     0.00     0.0        0.0  ...     0.00    0.00        1.00    1
# 18     1.00     0.0        0.0  ...     0.00    0.00        1.00    1
# 19     1.00     0.0        0.0  ...     0.00    0.00        6.00    1
# 20     1.00     0.0        0.0  ...     0.00    0.00        1.00    1
# 21     2.00     0.0        0.0  ...     5.00   10.00        7.00   10
# 22     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 23     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 24     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 25     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 26     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 27     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 28     3.36     0.0        0.0  ...     0.00    4.00        2.00    1
# 29     0.00     0.0        0.0  ...     0.00    0.00       58.00    1
# 30      NaN     NaN        NaN  ...     6.16   12.13        8.60   10
# 31     0.00     0.0        0.0  ...     2.00   15.00        7.50   18
# 32     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 33     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 34     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 35     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 36     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 37     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 38     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 39     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 40     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 41     2.00     0.0        0.0  ...     5.00   11.00        7.00    1
# 42     0.00     0.0        1.0  ...      NaN     NaN        5.00    1
# 43     0.00     0.0        1.0  ...      NaN     NaN        1.90    1
# 44     0.00     0.0        0.0  ...     1.40   14.50        7.61   18
# 45    24.00     0.0        0.0  ...     1.40     NaN        7.61   44
# 46     0.00     0.0        0.0  ...      NaN     NaN       42.00    1
# 47     0.00     0.0        0.0  ...      NaN     NaN       40.00    1
# 48     0.00     0.0        0.0  ...      NaN     NaN       14.00    1
# 49     0.00     0.0        0.0  ...      NaN     NaN       58.00    1
#
#       com mean      com SD    Common unit    ori mean      ori SD  \
# 0     0.649038    0.420673          ng/ml    0.649038    0.420673
# 1     0.129808    0.072115          ng/ml    0.129808    0.072115
# 2     0.688000         NaN          ng/ml    0.688000    0.000000
# 3     0.872000    0.159349          ng/ml    0.872000    0.159349
# 4     0.969000    0.000000          ng/ml    0.969000    0.000000
# 5     6.500000    4.500000          ng/ml    6.500000    4.500000
# 6     5.220000    3.400000          ng/ml    5.220000    3.400000
# 7     9.020000    9.020000          ng/ml    9.020000    9.020000
# 8    50.500000    0.000000     nmolBCE/l    50.500000    0.000000
# 9    59.000000    0.000000     nmolBCE/l    59.000000    0.000000
# 10   76.500000    0.000000     nmolBCE/l    76.500000    0.000000
# 11   79.000000    0.000000     nmolBCE/l    79.000000    0.000000
# 12   47.200000    0.000000     nmolBCE/l    47.200000    0.000000
# 13   38.000000    0.000000     nmolBCE/l    38.000000    0.000000
# 14   58.500000    0.000000     nmolBCE/l    58.500000    0.000000
# 15   80.000000    0.000000     nmolBCE/l    80.000000    0.000000
# 16   36.600000    0.000000     nmolBCE/l    36.600000    0.000000
# 17   66.600000    0.000000     nmolBCE/l    66.600000    0.000000
# 18   47.800000    0.000000     nmolBCE/l    47.800000    0.000000
# 19   46.500000    0.000000     nmolBCE/l    46.500000    0.000000
# 20   92.000000    0.000000     nmolBCE/l    92.000000    0.000000
# 21   85.480000   39.560000     nmolBCE/l    85.480000   39.560000
# 22   -2.228997    0.000000        T-score   -2.228997    0.000000
# 23   -1.470190    0.000000        T-score   -1.470190    0.000000
# 24   -0.995935    0.000000        T-score   -0.995935    0.000000
# 25   -0.569106    0.000000        T-score   -0.569106    0.000000
# 26    0.426829    0.000000        T-score    0.426829    0.000000
# 27    3.794038    0.000000        T-score    3.794038    0.000000
# 28    5.216802    0.000000        T-score    5.216802    0.000000
# 29    7.400000    0.000000  nmol/mmol Cr     7.400000    0.000000
# 30   48.330000   17.970000  nmol/mmol Cr    48.330000   17.970000
# 31   26.700000   13.500000  nmol/mmol Cr    26.700000   13.500000
# 32   11.936440    0.000000  nmol/mmol Cr    43.520763    0.000000
# 33   27.686218    0.000000  nmol/mmol Cr   100.945120    0.000000
# 34   28.547360    0.000000  nmol/mmol Cr   104.084880    0.000000
# 35   28.916131    0.000000  nmol/mmol Cr   105.429436    0.000000
# 36   33.592638    0.000000  nmol/mmol Cr   122.480178    0.000000
# 37   43.928367    0.000000  nmol/mmol Cr   160.164681    0.000000
# 38   46.882590    0.000000  nmol/mmol Cr   170.935904    0.000000
# 39   51.311899    0.000000  nmol/mmol Cr   187.085350    0.000000
# 40   53.157782    0.000000  nmol/mmol Cr   193.815517    0.000000
# 41   57.955862    0.000000  nmol/mmol Cr   211.309519    0.000000
# 42   58.660000    0.000000  nmol/mmol Cr    58.660000    0.000000
# 43   63.900000    0.000000  nmol/mmol Cr    63.900000    0.000000
# 44   66.200000    6.700000  nmol/mmol Cr    66.200000    6.700000
# 45  662.000000  291.000000  nmol/mmol Cr   662.000000  291.000000
# 46   19.300000    0.000000  nmol/mmol Cr    19.300000    0.000000
# 47   24.400000    0.000000  nmol/mmol Cr    24.400000    0.000000
# 48   32.900000    0.000000  nmol/mmol Cr    32.900000    0.000000
# 49   42.700000    0.000000  nmol/mmol Cr    42.700000    0.000000
#
#              Ori unit
# 0               ng/ml
# 1               ng/ml
# 2               ng/ml
# 3               ng/ml
# 4               ng/ml
# 5               ng/ml
# 6               ng/ml
# 7               ng/ml
# 8          nmolBCE/l
# 9          nmolBCE/l
# 10         nmolBCE/l
# 11         nmolBCE/l
# 12         nmolBCE/l
# 13         nmolBCE/l
# 14         nmolBCE/l
# 15         nmolBCE/l
# 16         nmolBCE/l
# 17         nmolBCE/l
# 18         nmolBCE/l
# 19         nmolBCE/l
# 20         nmolBCE/l
# 21         nmolBCE/l
# 22            T-score
# 23            T-score
# 24            T-score
# 25            T-score
# 26            T-score
# 27            T-score
# 28            T-score
# 29      nmol/mmol Cr
# 30       nmol/mmol Cr
# 31      nmol/mmol Cr
# 32            ug/g Cr
# 33            ug/g Cr
# 34            ug/g Cr
# 35            ug/g Cr
# 36            ug/g Cr
# 37            ug/g Cr
# 38            ug/g Cr
# 39            ug/g Cr
# 40            ug/g Cr
# 41            ug/g Cr
# 42             nM/mM
# 43             nM/mM
# 44      nmol/mmol cr
# 45       (nmol/mmol)
# 46  nmol BCE/mmol Cr
# 47  nmol BCE/mmol Cr
# 48  nmol BCE/mmol Cr
# 49      nmol/mmol Cr
#
# [50 rows x 23 columns]

# %% [markdown]
# ## Preprocesing

# %%
# Add a new column for IPD data
df['ipd_data'] = 0 # Aggregated data
df.loc[df.n == 1, 'ipd_data'] = 1 # IPD data

# %% [markdown]
# # IPD VS AGG by marker

# %%
# Define type of data in each column :)
df = df.astype({"Sex": str, "com mean": float})
df.dtypes
# Out:
# Code              int64
# Author, year     object
# Sex              object
# Male             object
# Female           object
# Type I          float64
# Type III        float64
# Type IV         float64
# Type V          float64
# Type XIII       float64
# NA                int64
# Note             object
# marker           object
# min age         float64
# max age         float64
# average age     float64
# n                 int64
# com mean        float64
# com SD          float64
# Common unit      object
# ori mean        float64
# ori SD          float64
# Ori unit         object
# ipd_data          int64
# dtype: object

# %%
# Unique values for Sex column
df.Sex.unique()
# Out:
# array(['MF', 'NR', 'M', 'F'], dtype=object)

# %%
# Unique values for marker column
df.marker.unique()
# Out:
# array(['sCTX', 'sCTX ', 'sCTX1', 'sNTX', 'uCTX', 'uDPD', 'uNTX'],
#       dtype=object)

# %%
# Replace of irregular values
df.loc[df.marker == 'sCTX ', 'marker'] = 'sCTX'
df.loc[df.marker == 'sCTX1', 'marker'] = 'sCTX'
df.marker.unique()
# Out:
# array(['sCTX', 'sNTX', 'uCTX', 'uDPD', 'uNTX'], dtype=object)

# %% [markdown]
# ## Grouping data by marker

# %%
gp = df.groupby('marker')

# %%
# Iteration example with a smile
for name, group in gp:
    print(name) # name of the marker
    print(group) # table of records (articles) that belong to the marker
print("🙂")
# Out:
# sCTX
#    Code               Author, year Sex Male Female  Type I  Type III  Type IV  \
# 0   306          Zhang et al, 2022  MF   83     44    80.0      10.0     24.0
# 1   306          Zhang et al, 2022  MF    7     15    17.0       2.0      2.0
# 2   128  Hryhorovskyi et al., 2015  NR    x      x     1.0       0.0      0.0
# 3   128  Hryhorovskyi et al., 2015  NR    x      x     0.0       3.0      0.0
# 4   203            Xu et al., 2019   M    1      0     0.0       0.0      0.0
# 5   117           D’Eufemia., 2014  MF   11      7    18.0       0.0      0.0
# 6   118     D’Eufemia et al., 2017  MF    5      7    12.0       0.0      0.0
# 7   118     D’Eufemia et al., 2017  MF    4      2     6.0       0.0      0.0
#
#    Type V  Type XIII  ...  max age average age    n  com mean    com SD  \
# 0    13.0        0.0  ...     18.8        14.3  127  0.649038  0.420673
# 1     1.0        0.0  ...     49.8        38.3   22  0.129808  0.072115
# 2     0.0        0.0  ...     17.0        11.0    1  0.688000       NaN
# 3     0.0        0.0  ...     17.0        11.0    3  0.872000  0.159349
# 4     0.0        1.0  ...      0.0        15.0    1  0.969000  0.000000
# 5     0.0        0.0  ...      6.2         4.4   18  6.500000  4.500000
# 6     0.0        0.0  ...      6.8         5.3   12  5.220000  3.400000
# 7     0.0        0.0  ...      5.3         4.2    6  9.020000  9.020000
#
#    Common unit  ori mean    ori SD  Ori unit ipd_data
# 0        ng/ml  0.649038  0.420673     ng/ml        0
# 1        ng/ml  0.129808  0.072115     ng/ml        0
# 2        ng/ml  0.688000  0.000000     ng/ml        1
# 3        ng/ml  0.872000  0.159349     ng/ml        0
# 4        ng/ml  0.969000  0.000000     ng/ml        1
# 5        ng/ml  6.500000  4.500000     ng/ml        0
# 6        ng/ml  5.220000  3.400000     ng/ml        0
# 7        ng/ml  9.020000  9.020000     ng/ml        0
#
# [8 rows x 24 columns]
# sNTX
#     Code             Author, year Sex Male Female  Type I  Type III  Type IV  \
# 8     30     Kitaoka et al., 2011   M    1      0     1.0       0.0      0.0
# 9     30     Kitaoka et al., 2011   M    1      0     1.0       0.0      0.0
# 10    30     Kitaoka et al., 2011   F    0      1     1.0       0.0      0.0
# 11    30     Kitaoka et al., 2011   M    1      0     1.0       0.0      0.0
# 12    30     Kitaoka et al., 2011   F    0      1     1.0       0.0      0.0
# 13    30     Kitaoka et al., 2011   M    1    NaN     1.0       0.0      0.0
# 14    30     Kitaoka et al., 2011   F    0      1     1.0       0.0      0.0
# 15    30     Kitaoka et al., 2011   M    1      0     1.0       0.0      0.0
# 16    30     Kitaoka et al., 2011   F    0      1     1.0       0.0      0.0
# 17    30     Kitaoka et al., 2011   M    1      0     1.0       0.0      0.0
# 18    30     Kitaoka et al., 2011   F    0      1     0.0       0.0      1.0
# 19    30     Kitaoka et al., 2011   M    1      0     0.0       0.0      1.0
# 20    30     Kitaoka et al., 2011   F    0      1     0.0       0.0      1.0
# 21   112  Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0      2.0
#
#     Type V  Type XIII  ...  max age average age   n  com mean  com SD  \
# 8      0.0        0.0  ...      0.0         7.0   1     50.50    0.00
# 9      0.0        0.0  ...      0.0         4.0   1     59.00    0.00
# 10     0.0        0.0  ...      0.0        10.0   1     76.50    0.00
# 11     0.0        0.0  ...      0.0        12.0   1     79.00    0.00
# 12     0.0        0.0  ...      0.0         4.0   1     47.20    0.00
# 13     0.0        0.0  ...      0.0         4.0   1     38.00    0.00
# 14     0.0        0.0  ...      0.0         4.0   1     58.50    0.00
# 15     0.0        0.0  ...      0.0        14.0   1     80.00    0.00
# 16     0.0        0.0  ...      0.0        13.0   1     36.60    0.00
# 17     0.0        0.0  ...      0.0         1.0   1     66.60    0.00
# 18     0.0        0.0  ...      0.0         1.0   1     47.80    0.00
# 19     0.0        0.0  ...      0.0         6.0   1     46.50    0.00
# 20     0.0        0.0  ...      0.0         1.0   1     92.00    0.00
# 21     0.0        0.0  ...     10.0         7.0  10     85.48   39.56
#
#     Common unit  ori mean  ori SD    Ori unit ipd_data
# 8    nmolBCE/l      50.50    0.00  nmolBCE/l         1
# 9    nmolBCE/l      59.00    0.00  nmolBCE/l         1
# 10   nmolBCE/l      76.50    0.00  nmolBCE/l         1
# 11   nmolBCE/l      79.00    0.00  nmolBCE/l         1
# 12   nmolBCE/l      47.20    0.00  nmolBCE/l         1
# 13   nmolBCE/l      38.00    0.00  nmolBCE/l         1
# 14   nmolBCE/l      58.50    0.00  nmolBCE/l         1
# 15   nmolBCE/l      80.00    0.00  nmolBCE/l         1
# 16   nmolBCE/l      36.60    0.00  nmolBCE/l         1
# 17   nmolBCE/l      66.60    0.00  nmolBCE/l         1
# 18   nmolBCE/l      47.80    0.00  nmolBCE/l         1
# 19   nmolBCE/l      46.50    0.00  nmolBCE/l         1
# 20   nmolBCE/l      92.00    0.00  nmolBCE/l         1
# 21   nmolBCE/l      85.48   39.56  nmolBCE/l         0
#
# [14 rows x 24 columns]
# uCTX
#     Code          Author, year Sex Male Female  Type I  Type III  Type IV  \
# 22    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
# 23    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
# 24    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
# 25    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
# 26    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
# 27    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
# 28    11  Pressac et al., 2002  MF    8      8    6.88      5.76     3.36
#
#     Type V  Type XIII  ...  max age average age  n  com mean  com SD  \
# 22     0.0        0.0  ...      4.0         2.0  1 -2.228997     0.0
# 23     0.0        0.0  ...      4.0         2.0  1 -1.470190     0.0
# 24     0.0        0.0  ...      4.0         2.0  1 -0.995935     0.0
# 25     0.0        0.0  ...      4.0         2.0  1 -0.569106     0.0
# 26     0.0        0.0  ...      4.0         2.0  1  0.426829     0.0
# 27     0.0        0.0  ...      4.0         2.0  1  3.794038     0.0
# 28     0.0        0.0  ...      4.0         2.0  1  5.216802     0.0
#
#     Common unit  ori mean  ori SD  Ori unit ipd_data
# 22      T-score -2.228997     0.0   T-score        1
# 23      T-score -1.470190     0.0   T-score        1
# 24      T-score -0.995935     0.0   T-score        1
# 25      T-score -0.569106     0.0   T-score        1
# 26      T-score  0.426829     0.0   T-score        1
# 27      T-score  3.794038     0.0   T-score        1
# 28      T-score  5.216802     0.0   T-score        1
#
# [7 rows x 24 columns]
# uDPD
#     Code                 Author, year Sex Male Female  Type I  Type III  \
# 29    63         Iwamoto et al., 2002   M    1      0     1.0       0.0
# 30    69      Hoyer-Kuhn et al., 2019  MF    0      3     NaN       3.0
# 31    98  Zacharin & Kanumakala, 2004  NR    0      0     0.0       0.0
# 32   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 33   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 34   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 35   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 36   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 37   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 38   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 39   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 40   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 41   112      Hoyer-Kuhn et al., 2016  MF    7      3     NaN       0.0
# 42   202       Asharani  et al., 2012  NR    1      0     0.0       0.0
# 43   202       Asharani  et al., 2012  NR    1      0     0.0       0.0
# 44   206       Zacharin &Bateman 2002  NR    0      0     0.0       0.0
#
#     Type IV  Type V  Type XIII  ...  max age average age   n   com mean  \
# 29      0.0     0.0        0.0  ...     0.00       58.00   1   7.400000
# 30      NaN     NaN        NaN  ...    12.13        8.60  10  48.330000
# 31      0.0     0.0        0.0  ...    15.00        7.50  18  26.700000
# 32      2.0     0.0        0.0  ...    11.00        7.00   1  11.936440
# 33      2.0     0.0        0.0  ...    11.00        7.00   1  27.686218
# 34      2.0     0.0        0.0  ...    11.00        7.00   1  28.547360
# 35      2.0     0.0        0.0  ...    11.00        7.00   1  28.916131
# 36      2.0     0.0        0.0  ...    11.00        7.00   1  33.592638
# 37      2.0     0.0        0.0  ...    11.00        7.00   1  43.928367
# 38      2.0     0.0        0.0  ...    11.00        7.00   1  46.882590
# 39      2.0     0.0        0.0  ...    11.00        7.00   1  51.311899
# 40      2.0     0.0        0.0  ...    11.00        7.00   1  53.157782
# 41      2.0     0.0        0.0  ...    11.00        7.00   1  57.955862
# 42      0.0     0.0        1.0  ...      NaN        5.00   1  58.660000
# 43      0.0     0.0        1.0  ...      NaN        1.90   1  63.900000
# 44      0.0     0.0        0.0  ...    14.50        7.61  18  66.200000
#
#     com SD    Common unit    ori mean  ori SD       Ori unit ipd_data
# 29    0.00  nmol/mmol Cr     7.400000    0.00  nmol/mmol Cr         1
# 30   17.97  nmol/mmol Cr    48.330000   17.97   nmol/mmol Cr        0
# 31   13.50  nmol/mmol Cr    26.700000   13.50  nmol/mmol Cr         0
# 32    0.00  nmol/mmol Cr    43.520763    0.00        ug/g Cr        1
# 33    0.00  nmol/mmol Cr   100.945120    0.00        ug/g Cr        1
# 34    0.00  nmol/mmol Cr   104.084880    0.00        ug/g Cr        1
# 35    0.00  nmol/mmol Cr   105.429436    0.00        ug/g Cr        1
# 36    0.00  nmol/mmol Cr   122.480178    0.00        ug/g Cr        1
# 37    0.00  nmol/mmol Cr   160.164681    0.00        ug/g Cr        1
# 38    0.00  nmol/mmol Cr   170.935904    0.00        ug/g Cr        1
# 39    0.00  nmol/mmol Cr   187.085350    0.00        ug/g Cr        1
# 40    0.00  nmol/mmol Cr   193.815517    0.00        ug/g Cr        1
# 41    0.00  nmol/mmol Cr   211.309519    0.00        ug/g Cr        1
# 42    0.00  nmol/mmol Cr    58.660000    0.00         nM/mM         1
# 43    0.00  nmol/mmol Cr    63.900000    0.00         nM/mM         1
# 44    6.70  nmol/mmol Cr    66.200000    6.70  nmol/mmol cr         0
#
# [16 rows x 24 columns]
# uNTX
#     Code          Author, year Sex Male Female  Type I  Type III  Type IV  \
# 45    38    Rauch et al., 2002  MF   22     22    11.0      10.0     24.0
# 46    39   Uehara et al., 2017   F    0      1     1.0       0.0      0.0
# 47    39   Uehara et al., 2017   F    0      1     1.0       0.0      0.0
# 48    39   Uehara et al., 2017   F    0      1     1.0       0.0      0.0
# 49    63  Iwamoto et al., 2002   M    1      0     1.0       0.0      0.0
#
#     Type V  Type XIII  ...  max age average age   n  com mean  com SD  \
# 45     0.0        0.0  ...      NaN        7.61  44     662.0   291.0
# 46     0.0        0.0  ...      NaN       42.00   1      19.3     0.0
# 47     0.0        0.0  ...      NaN       40.00   1      24.4     0.0
# 48     0.0        0.0  ...      NaN       14.00   1      32.9     0.0
# 49     0.0        0.0  ...      NaN       58.00   1      42.7     0.0
#
#       Common unit  ori mean  ori SD           Ori unit ipd_data
# 45  nmol/mmol Cr      662.0   291.0       (nmol/mmol)         0
# 46  nmol/mmol Cr       19.3     0.0  nmol BCE/mmol Cr         1
# 47  nmol/mmol Cr       24.4     0.0  nmol BCE/mmol Cr         1
# 48  nmol/mmol Cr       32.9     0.0  nmol BCE/mmol Cr         1
# 49  nmol/mmol Cr       42.7     0.0      nmol/mmol Cr         1
#
# [5 rows x 24 columns]
# 🙂

# %%
# Iteration based on the example above
for name, group in gp:
    plt.figure() # create a figure
    plt.title(name) # place the marker name as the title of the figure
    sns.swarmplot( # this creates a swarm plot
        data = group, # based on this table (that comes from the gruops created before)
        x ='ipd_data', # this is the name of the x column
        y ='com mean', # the same for y axis
        hue="Sex" # colour points by some column
    ) 
    sns.violinplot(data = group, x = "ipd_data", y = "com mean", color='gray', inner="quartile")
    plt.show() # this shows the figure and "ends" the figure environment
               # this line and the 3rd makes an environment for figures
               # so we can combine multiple plots into a same figure
